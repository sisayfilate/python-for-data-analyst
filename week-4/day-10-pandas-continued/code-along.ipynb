# %%
import pandas as pd
import numpy as np

# %%
file_path = "data/tmdb-movies.csv"
df = pd.read_csv(file_path)

# %%
cols = ['genres', 'production_companies', 'release_date', 'budget_adj', 'revenue_adj']
temp_df = df[cols]
print(temp_df.dtypes)
temp_df.sort_values(by=['budget_adj'], ascending=True).head()
# Out:
# genres                   object
# production_companies     object
# release_date             object
# budget_adj              float64
# revenue_adj             float64
# dtype: object
#                  genres production_companies release_date  budget_adj  \
# 5329             Comedy  Touchstone Pictures      4/25/97         0.0
# 3838  Fantasy|Adventure      ZDF Enterprises     10/10/11         0.0
# 3837    Horror|Thriller     After Dark Films      1/28/11         0.0
# 3836    Horror|Thriller                  NaN      8/23/11         0.0
# 3835  Music|Documentary                  NaN      10/5/11         0.0
#
#        revenue_adj
# 5329  3.971507e+07
# 3838  0.000000e+00
# 3837  0.000000e+00
# 3836  0.000000e+00
# 3835  0.000000e+00

# %%
temp_df.sort_values(by=['budget_adj'], ascending=False).head()
# Out:
#                                          genres  \
# 2244  Adventure|Fantasy|Action|Western|Thriller
# 3375                   Adventure|Action|Fantasy
# 7387                   Adventure|Fantasy|Action
# 6570   Adventure|Fantasy|Action|Science Fiction
# 5231                     Drama|Romance|Thriller
#
#                                    production_companies release_date  \
# 2244                           Boram Entertainment Inc.      12/2/10
# 3375  Walt Disney Pictures|Jerry Bruckheimer Films|M...      5/11/11
# 7387  Walt Disney Pictures|Jerry Bruckheimer Films|S...      5/19/07
# 6570  DC Comics|Legendary Pictures|Warner Bros.|Bad ...      6/28/06
# 5231  Paramount Pictures|Twentieth Century Fox Film ...     11/18/97
#
#         budget_adj   revenue_adj
# 2244  4.250000e+08  1.108757e+07
# 3375  3.683713e+08  9.904175e+08
# 7387  3.155006e+08  1.010654e+09
# 6570  2.920507e+08  4.230205e+08
# 5231  2.716921e+08  2.506406e+09

# %%
temp_df = temp_df.copy()
temp_df.loc[:,['budget_adj','revenue_adj']] = temp_df.loc[:,['budget_adj','revenue_adj']].astype(np.int64)
# df['column name'] = df['column name'].astype('Int64')
# df['column name'] = df['column name'].fillna(0).astype(np.int64)

# %%
temp_df['profit'] = temp_df.revenue_adj - temp_df.budget_adj
temp_df['profit'] = temp_df['profit'].map('{:,d}'.format)
temp_df.sort_values(by=['profit'], ascending=False).head()
# Out:
#                                  genres  \
# 8     Family|Animation|Adventure|Comedy
# 697                            Thriller
# 6966                      Romance|Drama
# 8000              Action|Crime|Thriller
# 2490         Drama|Comedy|Crime|Romance
#
#                                production_companies release_date  budget_adj  \
# 8     Universal Pictures|Illumination Entertainment      6/17/15    68079970
# 697                     Ego Film Arts|The Film Farm      6/10/14           0
# 6966                                New Line Cinema      6/25/04    33478916
# 8000                                   Warner Bros.      12/8/83    48164863
# 2490                 United Artists|Irish Dreamtime       8/6/99    62834536
#
#       revenue_adj       profit
# 8      1064192016  996,112,046
# 697        990336      990,336
# 6966    133457615   99,978,699
# 8000    148090959   99,926,096
# 2490    162722051   99,887,515

# %%
temp_df.sort_values(by=['profit'], ascending=True).head()
# Out:
#                              genres  \
# 3065    Comedy|Drama|Family|Romance
# 8801                    Drama|Music
# 3104  Drama|Fantasy|Science Fiction
# 3966                          Drama
# 5752                          Drama
#
#                                    production_companies release_date  \
# 3065  Paramount Pictures|Nickelodeon Movies|Stella-d...      7/25/08
# 8801                                  Columbia Pictures      5/12/00
# 3104                                                NaN       1/1/08
# 3966  Lou Yi Inc.|Cin̩a|Kasander Film Company|Busy ...      8/31/02
# 5752                  Parada Film|Hai Hui Entertainment       3/8/13
#
#       budget_adj  revenue_adj      profit
# 3065           1            0          -1
# 8801    22793258     21781395  -1,011,863
# 3104     1012786            0  -1,012,786
# 3966     1575939       542779  -1,033,160
# 5752     1033380            0  -1,033,380

# %%
temp_df[temp_df['profit'] == max(temp_df.profit)].head()
# Out:
#                               genres  \
# 8  Family|Animation|Adventure|Comedy
#
#                             production_companies release_date  budget_adj  \
# 8  Universal Pictures|Illumination Entertainment      6/17/15    68079970
#
#    revenue_adj       profit
# 8   1064192016  996,112,046

# %%
temp_df = temp_df.copy()
temp_df['release_year'] = pd.to_datetime(temp_df['release_date']).dt.year
# kesete way 
# pd.DatetimeIndex(movies_df['release_date']).year 
# abdu way 
# movies_df['year'] = movies_df.release_date.map(lambda x: int(x.split('/')[2]) + 2000 if int(x.split('/')[2]) < 22 else int(x.split('/')[2]) + 1900) 
print(temp_df.dtypes)
# temp_df.groupby('rea')
# Out:
# genres                  object
# production_companies    object
# release_date            object
# budget_adj               int64
# revenue_adj              int64
# profit                  object
# release_year             int64
# dtype: object

# %%
count_df = temp_df.groupby('release_year').size().reset_index().rename(columns={0:'count'})
count_df.sort_values(by=['count'], ascending=False).head()
# count_df.rename(columns={0,'count'}, inplace=True).head()
# psg_grouped = psg_df[['customer_id','amount']].groupby('customer_id').sum().reset_index().rename(columns={'amount':'total_spend'})
# Out:
#     release_year  count
# 42          2014    700
# 41          2013    659
# 43          2015    629
# 40          2012    588
# 39          2011    540

# %%
print(df.shape)
df.head()

# 1. select only this (genres, production_companies, release_date, budget_adj, revenue_adj) feilds and save the dataframe as a new dataframe named move_df
# 2. sort the new dataframe by "budget_adj" both in ascending and descending order
# 3. create a new column that calucate the profit each move made i.e (revenue_adj minues budget_adj)
# 4. get which movie made the most many and how much was that 
# 5. group by dataframe by release_date and count how many movies was realleased per year

# sort by revenue_adj
# Out:
# (10866, 21)
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# ...

# %%
df.columns
# Out:
# Index(['id', 'imdb_id', 'popularity', 'budget', 'revenue', 'original_title',
#        'cast', 'homepage', 'director', 'tagline', 'keywords', 'overview',
#        'runtime', 'genres', 'production_companies', 'release_date',
#        'vote_count', 'vote_average', 'release_year', 'budget_adj',
#        'revenue_adj'],
#       dtype='object')

# %%
df.dtypes
# Out:
# id                        int64
# imdb_id                  object
# popularity              float64
# budget                    int64
# revenue                   int64
# original_title           object
# cast                     object
# homepage                 object
# director                 object
# tagline                  object
# keywords                 object
# overview                 object
# runtime                   int64
# genres                   object
# production_companies     object
# release_date             object
# vote_count                int64
# vote_average            float64
# release_year              int64
# budget_adj              float64
# revenue_adj             float64
# dtype: object

# %%
cols = ['budget','revenue','original_title','director']
df1= df[cols]
df1.head(3)
# Out:
#       budget     revenue      original_title          director
# 0  150000000  1513528810      Jurassic World   Colin Trevorrow
# 1  150000000   378436354  Mad Max: Fury Road     George Miller
# 2  110000000   295238201           Insurgent  Robert Schwentke

# %%
df_less_10m = df1[df1['budget'] < 10000000]
print(df_less_10m.shape)
df_less_10m.head(3)
# Out:
# (7435, 4)
#      budget   revenue original_title          director
# 30        0  29355203     Mr. Holmes       Bill Condon
# 35  6000000  35401758           Room  Lenny Abrahamson
# 36        0  22354572         Solace     Afonso Poyart

# %%
print(max(df.budget))
# Out:
# 425000000

# %%
df_highest_budget = df[df.budget == max(df.budget)]
df_highest_budget[cols].head()
# Out:
#          budget   revenue     original_title    director
# 2244  425000000  11087569  The Warrior's Way  Sngmoo Lee

# %%
df_highest_budget.loc[:,'budget'] = df_highest_budget.apply(lambda x: "{:,}".format(x['budget']), axis=1)
df_highest_budget.loc[:,'revenue'] = df_highest_budget['revenue'].map('{:,d}'.format)
# Out:
# /Users/sisayfilate/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)

# %%
df_highest_budget[cols].head()
# Out:
#            budget     revenue     original_title    director
# 2244  425,000,000  11,087,569  The Warrior's Way  Sngmoo Lee

# %%
temp_df = df[cols]
temp_df.dtypes
# Out:
# budget             int64
# revenue            int64
# original_title    object
# director          object
# dtype: object

# %%
df_400m_450m = df[(df['budget'] >= 100000000) & (df['budget'] <= 450000000) ][cols]
print(df_400m_450m.shape)
df_400m_450m.head()
# Out:
# (328, 4)
#       budget     revenue                original_title          director
# 0  150000000  1513528810                Jurassic World   Colin Trevorrow
# 1  150000000   378436354            Mad Max: Fury Road     George Miller
# 2  110000000   295238201                     Insurgent  Robert Schwentke
# 3  200000000  2068178225  Star Wars: The Force Awakens       J.J. Abrams
# 4  190000000  1506249360                     Furious 7         James Wan

# %%
temp_df = df[cols]
temp_df.head()
# Out:
#       budget     revenue                original_title          director
# 0  150000000  1513528810                Jurassic World   Colin Trevorrow
# 1  150000000   378436354            Mad Max: Fury Road     George Miller
# 2  110000000   295238201                     Insurgent  Robert Schwentke
# 3  200000000  2068178225  Star Wars: The Force Awakens       J.J. Abrams
# 4  190000000  1506249360                     Furious 7         James Wan

# %%
temp_df[temp_df['director'].str.startswith('G')].head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/q4/y7xqp5c55f3c58vcqh3nb1q80000gn/T/ipykernel_62405/124458241.py in <module>
# ----> 1 temp_df[temp_df['director'].str.startswith('G')].head()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3446
#    3447         # Do we have a (boolean) 1d indexer?
# -> 3448         if com.is_bool_indexer(key):
#    3449             return self._getitem_bool_array(key)
#    3450
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/common.py in is_bool_indexer(key)
#     137                     # Don't raise on e.g. ["A", "B", np.nan], see
#     138                     #  test_loc_getitem_list_of_labels_categoricalindex_with_na
# --> 139                     raise ValueError(na_msg)
#     140                 return False
#     141             return True
#
# ...

# %%
non_na_df = df[df['director'].isna()==False][cols]
print(non_na_df.shape)
non_na_df.head()
# Out:
# (10822, 4)
#       budget     revenue                original_title          director
# 0  150000000  1513528810                Jurassic World   Colin Trevorrow
# 1  150000000   378436354            Mad Max: Fury Road     George Miller
# 2  110000000   295238201                     Insurgent  Robert Schwentke
# 3  200000000  2068178225  Star Wars: The Force Awakens       J.J. Abrams
# 4  190000000  1506249360                     Furious 7         James Wan

# %%
na_df = df[df['director'].isna()==True][cols]
print(na_df.shape)
na_df.head()
# Out:
# (44, 4)
#       budget  revenue                         original_title director
# 532        0        0         Iliza Shlesinger: Freezing Hot      NaN
# 548        0        0             Sense8: Creating the World      NaN
# 556        0        0                         With This Ring      NaN
# 1032       0        0  Marvel Studios: Assembling a Universe      NaN
# 1054       0        0                     Unlocking Sherlock      NaN

# %%
wendy_df = na_df.join(non_na_df, on='dep_id', how='left')
wendy_df = na_df.join(non_na_df, on=['dep_id'], how='inner')
wendy_df = na_df.join(non_na_df, on=['dep_id','emp_id'], how='outer')

# %%
final_df = pd.DataFrame.join([df1, non_na_df, wendy_df,na_df], on=['emp_id', 'dept_id'], how=['left','outer','inner'])

# %%
df_1 = df_1.astype({'budget_adj':'int', 'revenue_adj': 'int'})

# %%
df_1.dtypes

# %%
df_1.head()
